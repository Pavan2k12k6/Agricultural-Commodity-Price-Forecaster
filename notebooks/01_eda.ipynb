# %% [markdown]
# # Agricultural Commodity Price Forecaster — EDA
#
# Open this notebook from the **project root** so Python can import `agr_forecast` (or run `pip install -e .` first).
#
# This notebook delegates heavy plotting to `agr_forecast.eda.run_eda_plots`.

# %%
from pathlib import Path

from agr_forecast.config import DATA_RAW, PROJECT_ROOT
from agr_forecast.eda import run_eda_plots

figures_dir = PROJECT_ROOT / "notebooks" / "figures"
figures_dir.mkdir(parents=True, exist_ok=True)
out = run_eda_plots(DATA_RAW, figures_dir)
print("Saved to:", out.resolve())

# %% [markdown]
# Optional: quick interactive preview of numeric columns with `pandas` profiling is left as an exercise.
